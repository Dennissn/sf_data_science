# %% [markdown]
# ### **ML-7: Оптимизация гиперпараметров. Практика**

# %% [markdown]
# #### Прогнозирование биологического ответа

# %% [markdown]
# *Основана на соревновании Kaggle: Predicting a Biological Response (https://www.kaggle.com/c/bioresponse)*

# %% [markdown]
# Необходимо предсказать биологический ответ молекул (столбец 'Activity') по их химическому составу (столбцы D1-D1776).
#
# Данные представлены в формате CSV.  Каждая строка представляет молекулу.
#
# - Первый столбец Activity содержит экспериментальные данные, описывающие фактический биологический ответ [0, 1];
# - Остальные столбцы D1-D1776 представляют собой молекулярные дескрипторы — это вычисляемые свойства, которые могут фиксировать некоторые характеристики молекулы, например размер, форму или состав элементов.
#
# Предварительная обработка не требуется, данные уже закодированы и нормализованы.
#
# В качестве метрики будем использовать F1-score.
#
# Необходимо обучить две модели: логистическую регрессию и случайный лес. Далее нужно сделать подбор гиперпараметров с помощью базовых и продвинутых методов оптимизации. Важно использовать все четыре метода (GridSeachCV, RandomizedSearchCV, Hyperopt, Optuna) хотя бы по разу, максимальное количество итераций не должно превышать 50.

# %% [markdown]
# ##### 1. Загрузка данных

# %%
#импорт библиотек
import numpy as np #для матричных вычислений
import pandas as pd #для анализа и предобработки данных

from sklearn import linear_model #линейные моделиё
from sklearn import ensemble #ансамбли
from sklearn import metrics #метрики
from sklearn.model_selection import train_test_split #сплитование выборки

# %%
data = pd.read_csv('_train_sem09.csv')
data.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...      0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...      1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...      0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...      0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
# 2      0      0      0
# 3      0      0      0
# 4      0      0      0
#
# [5 rows x 1777 columns]

# %%
X = data.drop(['Activity'], axis=1)
y = data['Activity']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state = 1, test_size = 0.2)

# %% [markdown]
# ##### 2. Базовые модели

# %%
random_state = 42

# %%
#Создаем объект класса логистическая регрессия
log_reg = linear_model.LogisticRegression(max_iter = 50)

#Обучаем модель
log_reg.fit(X_train, y_train)

#Выводим значения метрики 
y_test_pred = log_reg.predict(X_test)
print('Логистическая регрессия\nf1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# Логистическая регрессия
# f1_score на тестовом наборе: 0.79
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Создаем объект класса случайный лес
rf = ensemble.RandomForestClassifier(random_state=random_state)

#Обучаем модель
rf.fit(X_train, y_train)

#Выводим значения метрики 
y_test_pred = rf.predict(X_test)
print('Случайный лес\nf1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# Случайный лес
# f1_score на тестовом наборе: 0.81

# %% [markdown]
# ##### 3. Оптимизация гиперпараметров. Логистическая регрессия

# %% [markdown]
# 3.1 Логистическая регрессия. GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [
              {'penalty': ['l1', 'l2'] , # тип регуляризации
              'solver': ['saga'], # алгоритм оптимизации
               'C': [0.01, 0.1, 0.3, 0.5, 0.7, 0.9, 1]}, # уровень силы регуляризации

              {'penalty': ['l2'] , # тип регуляризации
              'solver': ['lbfgs'], # алгоритм оптимизации
               'C': [0.01, 0.1, 0.3, 0.5, 0.7, 0.9, 1]}, # уровень силы регуляризации

              {'penalty': ['none'] , # тип регуляризации
              'solver': ['saga']}, # алгоритм оптимизации
]
grid_search = GridSearchCV(
    estimator=linear_model.LogisticRegression(random_state=random_state, max_iter=50), 
    param_grid=param_grid, 
    cv=5,
    n_jobs = -1
)  
 
# %time - замеряет время выполнения
# %time grid_search.fit(X_train, y_train)

# %%
y_test_pred = grid_search.predict(X_test)
y_train_pred = grid_search.predict(X_train)

print("Наилучшие значения гиперпараметров: {}".format(grid_search.best_params_))
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1 на кросс-валидации: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# Наилучшие значения гиперпараметров: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# f1_score на тестовом наборе: 0.79
# f1 на кросс-валидации: 0.85

# %% [markdown]
# 3.2 Логистическая регрессия. RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(
    estimator=linear_model.LogisticRegression(random_state=random_state, max_iter=50), 
    param_distributions=param_grid, 
    cv=5,
    scoring='f1',
    n_jobs = -1
)  
 
random_search.fit(X_train, y_train)

# %%
y_test_pred = random_search.predict(X_test)
y_train_pred = random_search.predict(X_train)

print("Наилучшие значения гиперпараметров: {}".format(random_search.best_params_))
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1 на кросс-валидации: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# Наилучшие значения гиперпараметров: {'solver': 'saga', 'penalty': 'l1', 'C': 0.9}
# f1_score на тестовом наборе: 0.79
# f1 на кросс-валидации: 0.85

# %% [markdown]
# 3.3 Логистическая регрессия. HYPEROPT

# %%
from sklearn.model_selection import cross_val_score
import hyperopt
from hyperopt import hp, fmin, tpe, Trials

# %%
space = hp.choice('space', 
        [{'penalty': hp.choice('penalty', ['l1', 'l2']),
          'solver': 'saga',
          'C': hp.uniform('C0', 0.1, 1)
         },
        
         {'penalty': 'l2',
          'solver': 'lbfgs',
          'C': hp.uniform('C1', 0.1, 1)
         }]
)

# %%
def hyperopt_lr(params, cv=5, X=X_train, y=y_train, random_state=random_state):
    
    params = {'solver': params['solver'], 
              'penalty': params['penalty'], 
              'C': params['C']
             }
    # используем эту комбинацию для построения модели
    model = linear_model.LogisticRegression(
        **params, 
        random_state=random_state, 
        max_iter=50)
    
    # обучаем модель
    model.fit(X, y)
   
    # применим cross validation с тем же количеством фолдов
    score = cross_val_score(model, X, y, cv=cv, scoring="f1", n_jobs=-1).mean()

    # метрику необходимо минимизировать, поэтому ставим знак минус
    return -score

# %%
trials = Trials() # используется для логирования результатов

best=fmin(hyperopt_lr, # наша функция 
          space=space, # пространство гиперпараметров
          algo=tpe.suggest, # алгоритм оптимизации, установлен по умолчанию, задавать необязательно
          max_evals=20, # максимальное количество итераций
          trials=trials, # логирование результатов
          rstate=np.random.default_rng(random_state)# фиксируем для повторяемости результата
         )

# %%
print("Наилучшие значения гиперпараметров {}".format(best))
# Out:
# Наилучшие значения гиперпараметров {'C0': 0.8317887360487557, 'params': 0, 'penalty': 0}

# %%
# Обучаем модель с наилучшими значениями гиперпараметров
best_params = {
    'solver': 'saga',
    'penalty': 'l1',
    'C': 0.8317
}
# Создаем объект класса логистическая регрессия
hyperopt_log_reg = linear_model.LogisticRegression(
    **best_params,
    max_iter = 50)

#Обучаем модель
hyperopt_log_reg.fit(X_train, y_train)

y_test_pred = hyperopt_log_reg.predict(X_test)
y_train_pred = hyperopt_log_reg.predict(X_train)

# %%
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1_score на тренировочном наборе : {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# f1_score на тестовом наборе: 0.79
# f1_score на тренировочном наборе : 0.85

# %% [markdown]
# 3.4 Логистическая регрессия. OPTUNA

# %%
import optuna

# %%
def optuna_lr(trial):
  # задаем пространства поиска гиперпараметров
  penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
  solver = trial.suggest_categorical('solver', ['saga', 'lbfgs'])
  if solver == 'lbfgs':
    penalty = 'l2'
  C = trial.suggest_uniform('C', 0.1, 1)

  # создаем модель
  optuna_model = linear_model.LogisticRegression(
    penalty=penalty,
    solver=solver,
    C=C,
    random_state=random_state,
    max_iter = 50)
  
  # обучаем модель
  optuna_model.fit(X_train, y_train)
  # применим cross validation
  score = cross_val_score(optuna_model, X_train, y_train, cv=5, scoring='f1', n_jobs=-1).mean()
  
  return score

# %%
# cоздаем объект исследования
study = optuna.create_study(study_name="LogisticRegression", direction="maximize")
# ищем лучшую комбинацию гиперпараметров n_trials раз
study.optimize(optuna_lr, n_trials=50)
# Out:
# [I 2022-06-23 20:35:30,218] A new study created in memory with name: LogisticRegression
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:36:03,322] Trial 0 finished with value: 0.7812099257475398 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.3816965136390633}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:36:08,526] Trial 1 finished with value: 0.7668274168237027 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.8851744189521561}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:36:32,555] Trial 2 finished with value: 0.779918357538023 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.46311984520229066}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:36:37,786] Trial 3 finished with value: 0.7764133868125576 and parameters: {'penalty': 'l1', 'solver': 'lbfgs', 'C': 0.3650947572404143}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:36:42,982] Trial 4 finished with value: 0.7695470752048531 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.6824755476585733}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:36:48,294] Trial 5 finished with value: 0.7720776329069035 and parameters: {'penalty': 'l1', 'solver': 'lbfgs', 'C': 0.6770406507993055}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:36:53,570] Trial 6 finished with value: 0.7805939752841466 and parameters: {'penalty': 'l1', 'solver': 'lbfgs', 'C': 0.21633637992860405}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:36:58,747] Trial 7 finished with value: 0.7809541079861959 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21864003073066757}. Best is trial 0 with value: 0.7812099257475398.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:37:22,717] Trial 8 finished with value: 0.7825040336906931 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.11583785828928159}. Best is trial 8 with value: 0.7825040336906931.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:37:27,980] Trial 9 finished with value: 0.7818835255251765 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.20776047602947756}. Best is trial 8 with value: 0.7825040336906931.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:37:52,144] Trial 10 finished with value: 0.7827446319053449 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.11404785611884535}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:38:16,154] Trial 11 finished with value: 0.7817127069490185 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.10098722217104808}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:38:40,538] Trial 12 finished with value: 0.7809783675336355 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.1629689309121372}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:39:04,742] Trial 13 finished with value: 0.7804905645573288 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.3446454540958823}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:39:30,574] Trial 14 finished with value: 0.781240717510282 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.9890799781071303}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:39:54,950] Trial 15 finished with value: 0.780513528122693 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.5676161348745044}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:40:19,289] Trial 16 finished with value: 0.7806458359516328 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.3012398563695359}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:40:44,288] Trial 17 finished with value: 0.7814765974588535 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.10288157981429914}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:41:18,262] Trial 18 finished with value: 0.7785943315340312 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.5116011100240787}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:41:42,810] Trial 19 finished with value: 0.780282578410189 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.27992709089705203}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:42:07,350] Trial 20 finished with value: 0.7805171054903062 and parameters: {'penalty': 'l2', 'solver': 'saga', 'C': 0.6538273665687779}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-06-23 20:42:12,124] Trial 21 finished with value: 0.7820350193205308 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.207660433385147}. Best is trial 10 with value: 0.7827446319053449.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:49:00,982] Trial 38 finished with value: 0.7832227436093782 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.2400594050532965}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:49:33,694] Trial 39 finished with value: 0.7812184380154454 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.3896912567411571}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:50:06,707] Trial 40 finished with value: 0.778959251535865 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.5193632799758767}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:50:36,372] Trial 41 finished with value: 0.7832227436093782 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.23522286429084555}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:51:06,269] Trial 42 finished with value: 0.7817791460364043 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.23127443930028824}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:51:40,284] Trial 43 finished with value: 0.7810276578637944 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.33016180527273853}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:52:12,847] Trial 44 finished with value: 0.7828686888505372 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.25681749627094985}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:52:43,166] Trial 45 finished with value: 0.7815412410368083 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.2304372175007707}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:53:18,476] Trial 46 finished with value: 0.7805617092756286 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.3171600275502221}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:53:54,739] Trial 47 finished with value: 0.7794025488720544 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.3671608134326132}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:54:24,412] Trial 48 finished with value: 0.7810072460529196 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.1987481044604481}. Best is trial 32 with value: 0.7834563390478294.
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-06-23 20:54:53,848] Trial 49 finished with value: 0.783826349938544 and parameters: {'penalty': 'l1', 'solver': 'saga', 'C': 0.2508727773877056}. Best is trial 49 with value: 0.783826349938544.

# %%
# Создаем объект класса логистическая регрессия
optuna_log_reg = linear_model.LogisticRegression(
    **study.best_params,
    random_state=random_state,
    max_iter = 50)

#Обучаем модель
optuna_log_reg.fit(X_train, y_train)

y_test_pred = optuna_log_reg.predict(X_test)
y_train_pred = optuna_log_reg.predict(X_train)
# Out:
# /home/director/anaconda3/envs/DS/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1_score на тренировочном наборе : {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# f1_score на тестовом наборе: 0.79
# f1_score на тренировочном наборе : 0.82

# %% [markdown]
# ##### 4. Оптимизация гиперпараметров. Случайный лес

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# 4.1 Случайный лес. GridSearchCV

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 400],
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 25],
    'min_samples_leaf': [5, 10]
}

grid_search_rf = GridSearchCV(
    estimator=ensemble.RandomForestClassifier(random_state=random_state),
    param_grid=param_grid_rf, 
    scoring = 'f1',
    cv=5, 
    n_jobs = -1
)

grid_search_rf.fit(X_train, y_train)
y_train_pred = grid_search_rf.predict(X_train)
y_test_pred = grid_search_rf.predict(X_test)

# %%
print("Наилучшие значения гиперпараметров: {}".format(grid_search_rf.best_params_))
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1 на кросс-валидации: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# Наилучшие значения гиперпараметров: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_leaf': 5, 'n_estimators': 200}
# f1_score на тестовом наборе: 0.83
# f1 на кросс-валидации: 0.95

# %% [markdown]
# 4.2 Случайный лес. RandomizedSearchCV

# %%
random_search_rf = RandomizedSearchCV(
    estimator=ensemble.RandomForestClassifier(random_state=random_state), 
    param_distributions=param_grid_rf, 
    cv=5,
    scoring='f1',
    n_jobs = -1
)  
 
random_search_rf.fit(X_train, y_train)
y_train_pred = random_search_rf.predict(X_train)
y_test_pred = random_search_rf.predict(X_test)

# %%
print("Наилучшие значения гиперпараметров: {}".format(random_search_rf.best_params_))
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1 на кросс-валидации: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# Наилучшие значения гиперпараметров: {'n_estimators': 100, 'min_samples_leaf': 5, 'max_depth': 25, 'criterion': 'entropy'}
# f1_score на тестовом наборе: 0.82
# f1 на кросс-валидации: 0.95

# %% [markdown]
# 4.3 Случайный лес. HYPEROPT

# %%
space_rf = {
  'n_estimators': hp.quniform('n_estimators', 100, 400, 1),
  'criterion': hp.choice('criterion', ['gini', 'entropy']),
  'max_depth' : hp.quniform('max_depth', 1, 25, 1),
  'min_samples_leaf': hp.quniform('min_samples_leaf', 5, 10, 1)
}

# %%
def hyperopt_rf(params, cv=5, X=X_train, y=y_train, random_state=random_state):
    
    params = {
        'n_estimators': int(params['n_estimators']),
        'criterion': params['criterion'],
        'max_depth': int(params['max_depth']), 
        'min_samples_leaf': int(params['min_samples_leaf'])
    }
    
    # модель
    model = ensemble.RandomForestClassifier(
        **params, 
        random_state=random_state)
    
    # обучаем модель
    model.fit(X, y)
   
    # применим cross validation с тем же количеством фолдов
    score = cross_val_score(model, X, y, cv=cv, scoring="f1", n_jobs=-1).mean()

    # метрику необходимо минимизировать, поэтому ставим знак минус
    return -score

# %%
trials_rf = Trials() # используется для логирования результатов

best_rf = fmin(hyperopt_rf, # наша функция 
          space=space_rf, # пространство гиперпараметров
          algo=tpe.suggest, # алгоритм оптимизации, установлен по умолчанию, задавать необязательно
          max_evals=20, # максимальное количество итераций
          trials=trials_rf, # логирование результатов
          rstate=np.random.default_rng(random_state)# фиксируем для повторяемости результата
         )
# Out:
# 100%|██████████| 20/20 [04:24<00:00, 13.24s/trial, best loss: -0.8023598964806229]

# %%
print("Наилучшие значения гиперпараметров {}".format(best_rf))
# Out:
# Наилучшие значения гиперпараметров {'criterion': 1, 'max_depth': 12.0, 'min_samples_leaf': 6.0, 'n_estimators': 326.0}

# %%
best_params_rf = {
    'n_estimators': int(best_rf['n_estimators']),
    'criterion': 'entropy',
    'max_depth': int(best_rf['max_depth']),
    'min_samples_leaf': int(best_rf['min_samples_leaf'])
}

# Модель с лучшими параметрами
hyperopt_rf = ensemble.RandomForestClassifier(
    **best_params_rf, 
    random_state=random_state)

hyperopt_rf.fit(X_train, y_train)
y_train_pred = hyperopt_rf.predict(X_train)
y_test_pred = hyperopt_rf.predict(X_test)

# %%
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1_score на тренировочном наборе : {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# f1_score на тестовом наборе: 0.81
# f1_score на тренировочном наборе : 0.92

# %% [markdown]
# 4.4 Случайный лес. OPTUNA

# %%
def optuna_rf(trial):
  # пространство гиперпараметров
  n_estimators = trial.suggest_int('n_estimators', 100, 400, 1)
  criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
  max_depth = trial.suggest_int('max_depth', 1, 25, 1)
  min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 10, 1)

  # создаем модель
  optuna_model = ensemble.RandomForestClassifier(
        n_estimators=n_estimators,
        criterion=criterion,
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf, 
        random_state=random_state,
        n_jobs=-1
    )
  
  # обучаем модель
  optuna_model.fit(X_train, y_train)
  # применим cross validation
  score = cross_val_score(optuna_model, X_train, y_train, cv=5, scoring='f1', n_jobs=-1).mean()
  
  return score

# %%
# cоздаем объект исследования
study_rf = optuna.create_study(study_name="RandomForestClassifier", direction="maximize")
# ищем лучшую комбинацию гиперпараметров n_trials раз
study_rf.optimize(optuna_rf, n_trials=20)
# Out:
# [I 2022-06-23 21:50:33,627] A new study created in memory with name: RandomForestClassifier
# [I 2022-06-23 21:50:48,605] Trial 0 finished with value: 0.7969066468244452 and parameters: {'n_estimators': 224, 'criterion': 'entropy', 'max_depth': 23, 'min_samples_leaf': 9}. Best is trial 0 with value: 0.7969066468244452.
# [I 2022-06-23 21:51:04,829] Trial 1 finished with value: 0.7924141148507012 and parameters: {'n_estimators': 335, 'criterion': 'gini', 'max_depth': 25, 'min_samples_leaf': 9}. Best is trial 0 with value: 0.7969066468244452.
# [I 2022-06-23 21:51:09,127] Trial 2 finished with value: 0.7771263883662256 and parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10}. Best is trial 0 with value: 0.7969066468244452.
# [I 2022-06-23 21:51:16,286] Trial 3 finished with value: 0.8003191549619123 and parameters: {'n_estimators': 127, 'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.8003191549619123.
# [I 2022-06-23 21:51:23,379] Trial 4 finished with value: 0.7849588944404717 and parameters: {'n_estimators': 156, 'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.8003191549619123.
# [I 2022-06-23 21:51:39,059] Trial 5 finished with value: 0.8028123463429593 and parameters: {'n_estimators': 296, 'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 6}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:51:47,466] Trial 6 finished with value: 0.7985518909301467 and parameters: {'n_estimators': 152, 'criterion': 'entropy', 'max_depth': 21, 'min_samples_leaf': 8}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:51:50,916] Trial 7 finished with value: 0.7508348271611665 and parameters: {'n_estimators': 115, 'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 8}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:51:57,640] Trial 8 finished with value: 0.7648062195573017 and parameters: {'n_estimators': 227, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 7}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:52:04,334] Trial 9 finished with value: 0.7905468228674659 and parameters: {'n_estimators': 137, 'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 8}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:52:24,040] Trial 10 finished with value: 0.8027532601274621 and parameters: {'n_estimators': 393, 'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:52:47,274] Trial 11 finished with value: 0.801395795904931 and parameters: {'n_estimators': 399, 'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.8028123463429593.
# [I 2022-06-23 21:53:06,716] Trial 12 finished with value: 0.8048236492309757 and parameters: {'n_estimators': 324, 'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 4}. Best is trial 12 with value: 0.8048236492309757.
# [I 2022-06-23 21:53:26,841] Trial 13 finished with value: 0.8154705791119836 and parameters: {'n_estimators': 297, 'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.8154705791119836.
# [I 2022-06-23 21:53:47,379] Trial 14 finished with value: 0.8159601371465575 and parameters: {'n_estimators': 295, 'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}. Best is trial 14 with value: 0.8159601371465575.
# [I 2022-06-23 21:54:04,399] Trial 15 finished with value: 0.8134330470835647 and parameters: {'n_estimators': 262, 'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2}. Best is trial 14 with value: 0.8159601371465575.
# [I 2022-06-23 21:54:22,108] Trial 16 finished with value: 0.8148710184140159 and parameters: {'n_estimators': 278, 'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}. Best is trial 14 with value: 0.8159601371465575.
# [I 2022-06-23 21:54:43,407] Trial 17 finished with value: 0.811878669432385 and parameters: {'n_estimators': 350, 'criterion': 'entropy', 'max_depth': 23, 'min_samples_leaf': 3}. Best is trial 14 with value: 0.8159601371465575.
# [I 2022-06-23 21:54:55,733] Trial 18 finished with value: 0.8090066907916158 and parameters: {'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 3}. Best is trial 14 with value: 0.8159601371465575.
# [I 2022-06-23 21:55:12,678] Trial 19 finished with value: 0.8047912787746595 and parameters: {'n_estimators': 299, 'criterion': 'entropy', 'max_depth': 22, 'min_samples_leaf': 5}. Best is trial 14 with value: 0.8159601371465575.

# %%
print("Наилучшие значения гиперпараметров {}".format(study_rf.best_params))
# Out:
# Наилучшие значения гиперпараметров {'n_estimators': 295, 'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}

# %%
# Создаем объект класса логистическая регрессия
optuna_rf = ensemble.RandomForestClassifier(
    **study_rf.best_params, 
    random_state=random_state
)
    
#Обучаем модель
optuna_rf.fit(X_train, y_train)

y_test_pred = optuna_rf.predict(X_test)
y_train_pred = optuna_rf.predict(X_train)

# %%
print('f1 на кросс-валидации:', study_rf.best_value)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('f1_score на тренировочном наборе : {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
# Out:
# f1 на кросс-валидации: {} 0.8159601371465575
# f1_score на тестовом наборе: 0.82
# f1_score на тренировочном наборе : 0.99
